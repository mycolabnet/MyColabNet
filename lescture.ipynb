# %% [markdown]
# <a href="https://colab.research.google.com/github/mycolabnet/MyColabNet/blob/main/lescture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

number = np.random.rand(3, 2)
print(number, )
# Out:
# [[3.13735181e-01 4.72712266e-01]
#  [8.74785829e-01 5.85045671e-01]
#  [7.17477960e-01 5.58576881e-05]]
